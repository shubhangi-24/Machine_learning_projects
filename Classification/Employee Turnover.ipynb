# %% [markdown]
# Load Dataset

# %%
import pandas as pd 
df=pd.read_csv("Employee-turnover.csv")

# %%
df.head()
# Out:
#    Employee Count  Employee ID              Department               Job Role  \
# 0               1            1                   Sales        Sales Executive
# 1               1            2  Research & Development     Research Scientist
# 2               1            4  Research & Development  Laboratory Technician
# 3               1            5  Research & Development     Research Scientist
# 4               1            7  Research & Development  Laboratory Technician
#
#    Gender  Age Marital Status      Education Education Field  \
# 0  Female   41         Single        College   Life Sciences
# 1    Male   49        Married  Below College   Life Sciences
# 2    Male   37         Single        College           Other
# 3  Female   33        Married         Master   Life Sciences
# 4    Male   27        Married  Below College         Medical
#
#      Business Travel  ...  Total Working Years Years At Company  \
# ...

# %%
df.shape
# Out:
# (1470, 29)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 29 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Employee Count              1470 non-null   int64
#  1   Employee ID                 1470 non-null   int64
#  2   Department                  1470 non-null   object
#  3   Job Role                    1470 non-null   object
#  4   Gender                      1470 non-null   object
#  5   Age                         1470 non-null   int64
#  6   Marital Status              1470 non-null   object
#  7   Education                   1470 non-null   object
#  8   Education Field             1470 non-null   object
#  9   Business Travel             1470 non-null   object
#  10  Distance From Home (kms)    1470 non-null   int64
#  11  Job Involvement             1470 non-null   object
#  12  Job Level                   1470 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# Employee Count                0
# Employee ID                   0
# Department                    0
# Job Role                      0
# Gender                        0
# Age                           0
# Marital Status                0
# Education                     0
# Education Field               0
# Business Travel               0
# Distance From Home (kms)      0
# Job Involvement               0
# Job Level                     0
# Job Satisfaction              0
# Monthly Income (USD)          0
# Salary Hike (%)               0
# Stock Option Level            0
# Over Time                     0
# No. of Companies Worked       0
# Total Working Years           0
# Years At Company              0
# Years In Current Role         0
# Years Since Last Promotion    0
# Years With Curr Manager       0
# Environment Satisfaction      0
# Training Times Last Year      0
# Work Life Balance             0
# Relationship Satisfaction     0
# Attrition (Yes/No)            0
# ...

# %%
df.describe()
# Out:
#        Employee Count  Employee ID          Age  Distance From Home (kms)  \
# count          1470.0  1470.000000  1470.000000               1470.000000
# mean              1.0  1024.865306    36.923810                  9.192517
# std               0.0   602.024335     9.135373                  8.106864
# min               1.0     1.000000    18.000000                  1.000000
# 25%               1.0   491.250000    30.000000                  2.000000
# 50%               1.0  1020.500000    36.000000                  7.000000
# 75%               1.0  1555.750000    43.000000                 14.000000
# max               1.0  2068.000000    60.000000                 29.000000
#
#          Job Level  Monthly Income (USD)  Salary Hike (%)  Stock Option Level  \
# count  1470.000000           1470.000000      1470.000000         1470.000000
# mean      2.063946           6502.931293        14.951701            0.793878
# ...

# %% [markdown]
# Data PreProcessing

# %%
# There are no values in the data hence no need to impute missing values

# %% [markdown]
# Exploratory Data Analysis

# %%
import seaborn as sns

# %%
sns.countplot(df['Attrition (Yes/No)'])
# Out:
# C:\Users\shubhangi\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Attrition (Yes/No)', ylabel='count'>

# %%
sns.countplot(x='Department', hue='Attrition (Yes/No)',data=df,palette='colorblind')
# Out:
# <AxesSubplot:xlabel='Department', ylabel='count'>

# %%
import matplotlib.pyplot as plt
plt.subplots(figsize=(14,6))
sns.countplot(x='Job Role', hue='Attrition (Yes/No)',data=df,palette='colorblind')
# Out:
# <AxesSubplot:xlabel='Job Role', ylabel='count'>

# %%
plt.subplots(figsize=(14,6))
sns.countplot(x='Age', hue='Attrition (Yes/No)',data=df,palette='colorblind')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
plt.subplots(figsize=(14,6))
sns.countplot(x='Distance From Home (kms)', hue='Attrition (Yes/No)',data=df,palette='colorblind')
# Out:
# <AxesSubplot:xlabel='Distance From Home (kms)', ylabel='count'>

# %%
sns.countplot(x='Salary Hike (%)', hue='Attrition (Yes/No)',data=df,palette='colorblind')
# Out:
# <AxesSubplot:xlabel='Salary Hike (%)', ylabel='count'>

# %%
sns.countplot(x='Environment Satisfaction', hue='Attrition (Yes/No)',data=df,palette='colorblind')
# Out:
# <AxesSubplot:xlabel='Environment Satisfaction', ylabel='count'>

# %%
sns.countplot(x='Job Satisfaction', hue='Attrition (Yes/No)',data=df,palette='colorblind')
# Out:
# <AxesSubplot:xlabel='Job Satisfaction', ylabel='count'>

# %%
sns.countplot(x='Over Time', hue='Attrition (Yes/No)',data=df,palette='colorblind')
# Out:
# <AxesSubplot:xlabel='Over Time', ylabel='count'>

# %%
sns.countplot(x='Work Life Balance', hue='Attrition (Yes/No)',data=df,palette='colorblind')
# Out:
# <AxesSubplot:xlabel='Work Life Balance', ylabel='count'>

# %%
# next step is to deal with categorical data

# %%
df.value_counts('Department')
# Out:
# Department
# Research & Development    961
# Sales                     446
# Human Resources            63
# dtype: int64

# %%
#one hot label encoding

# %%
dict={'Research & Development':0,'Sales':1,'Human Resources':2}
df['Department']=df['Department'].map(dict)
df
# Out:
#       Employee Count  Employee ID  Department                   Job Role  \
# 0                  1            1           1            Sales Executive
# 1                  1            2           0         Research Scientist
# 2                  1            4           0      Laboratory Technician
# 3                  1            5           0         Research Scientist
# 4                  1            7           0      Laboratory Technician
# ...              ...          ...         ...                        ...
# 1465               1         2061           0      Laboratory Technician
# 1466               1         2062           0  Healthcare Representative
# 1467               1         2064           0     Manufacturing Director
# 1468               1         2065           1            Sales Executive
# 1469               1         2068           0      Laboratory Technician
#
#       Gender  Age Marital Status      Education Education Field  \
# ...

# %%
cols=['Job Role','Gender','Marital Status','Education','Education Field','Business Travel','Job Involvement','Job Satisfaction','Over Time','Environment Satisfaction','Work Life Balance','Relationship Satisfaction','Attrition (Yes/No)']
for col in cols:
    df[col]=pd.get_dummies(df[col],drop_first=True)

# %%
df.head()
# Out:
#    Employee Count  Employee ID  Department  Job Role  Gender  Age  \
# 0               1            1           1         0       0   41
# 1               1            2           0         0       1   49
# 2               1            4           0         0       1   37
# 3               1            5           0         0       0   33
# 4               1            7           0         0       1   27
#
#    Marital Status  Education  Education Field  Business Travel  ...  \
# 0               0          0                1                0  ...
# 1               1          1                1                1  ...
# 2               0          0                0                0  ...
# 3               1          0                1                1  ...
# 4               1          1                0                0  ...
#
#    Total Working Years  Years At Company  Years In Current Role  \
# 0                    8                 6                      4
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 29 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Employee Count              1470 non-null   int64
#  1   Employee ID                 1470 non-null   int64
#  2   Department                  1470 non-null   int64
#  3   Job Role                    1470 non-null   uint8
#  4   Gender                      1470 non-null   uint8
#  5   Age                         1470 non-null   int64
#  6   Marital Status              1470 non-null   uint8
#  7   Education                   1470 non-null   uint8
#  8   Education Field             1470 non-null   uint8
#  9   Business Travel             1470 non-null   uint8
#  10  Distance From Home (kms)    1470 non-null   int64
#  11  Job Involvement             1470 non-null   uint8
#  12  Job Level                   1470 non-null   int64
# ...

# %%
# Removing useless columns

# %%
cols=['Employee Count','Employee ID']
df=df.drop(columns=cols,axis=1)

# %%
# Correlation matrix

# %%
df.corr()
# Out:
#                             Department  Job Role    Gender       Age  \
# Department                    1.000000  0.542432 -0.000488 -0.007652
# Job Role                      0.542432  1.000000  0.036082 -0.029856
# Gender                       -0.000488  0.036082  1.000000 -0.036311
# Age                          -0.007652 -0.029856 -0.036311  1.000000
# Marital Status                0.029112  0.030995 -0.007804  0.083919
# Education                    -0.023002 -0.011672  0.034737 -0.188451
# Education Field              -0.130749 -0.063119  0.006770  0.016824
# Business Travel              -0.005460  0.001896 -0.022015 -0.024743
# Distance From Home (kms)      0.002196 -0.024089 -0.001851 -0.001686
# Job Involvement               0.014010  0.001020  0.013235 -0.025391
# Job Level                     0.088018 -0.100922 -0.039403  0.509604
# Job Satisfaction             -0.013407 -0.002068 -0.011880 -0.000371
# Monthly Income (USD)          0.056573 -0.092250 -0.031858  0.497855
# ...

# %%
plt.figure(figsize=(25,25))
correlation_matrix=df.corr()
sns.heatmap(correlation_matrix,annot=True,fmt='.02f')
plt.show()

# %% [markdown]
# Train Test Split

# %%
x=df.drop(columns=['Attrition (Yes/No)'],axis=1)
y=df['Attrition (Yes/No)']

# %%
print(x.shape)
print(y.shape)
# Out:
# (1470, 28)
# (1470,)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
# Out:
# (1029, 26)
# (441, 26)
# (1029,)

# %%
# Model 1
# Using Logistic Regression

from sklearn.linear_model import LogisticRegression
clf1=LogisticRegression()
clf1.fit(x_train,y_train)
y_test_pred=clf1.predict(x_test)
y_train_pred=clf1.predict(x_train)

from sklearn.metrics import accuracy_score
train_acc=accuracy_score(y_train,y_train_pred)
test_acc=accuracy_score(y_test,y_test_pred)
print('Training Acc=',train_acc*100)
print('Testing Acc=',test_acc*100)
# Out:
# Training Acc= 84.06219630709427
# Testing Acc= 84.80725623582767
# C:\Users\shubhangi\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from sklearn.metrics import confusion_matrix
cm1=confusion_matrix(y_test,y_test_pred)
print(cm1)

sns.heatmap(cm1,annot=True,cbar=False,fmt='.1f')
# Out:
# [[368   3]
#  [ 64   6]]
# <AxesSubplot:>

# %%
# Model 2 
# Using Decision Tree

from sklearn.tree import DecisionTreeClassifier
clf2=DecisionTreeClassifier()
clf2.fit(x_train,y_train)
y_test_pred=clf2.predict(x_test)
y_train_pred=clf2.predict(x_train)

from sklearn.metrics import accuracy_score
train_acc=accuracy_score(y_train,y_train_pred)
test_acc=accuracy_score(y_test,y_test_pred)
print('Training Acc=',train_acc*100)
print('Testing Acc=',test_acc*100)
# Out:
# Training Acc= 100.0
# Testing Acc= 78.2312925170068

# %%
from sklearn.metrics import confusion_matrix
cm2=confusion_matrix(y_test,y_test_pred)
print(cm2)

sns.heatmap(cm2,annot=True,cbar=False,fmt='.1f')
# Out:
# [[321  50]
#  [ 46  24]]
# <AxesSubplot:>

# %%
# Model 3
# Using SVM

from sklearn.svm import SVC
clf3=SVC()
clf3.fit(x_train,y_train)
y_test_pred=clf3.predict(x_test)
y_train_pred=clf3.predict(x_train)

from sklearn.metrics import accuracy_score
train_acc=accuracy_score(y_train,y_train_pred)
test_acc=accuracy_score(y_test,y_test_pred)
print('Training Acc=',train_acc*100)
print('Testing Acc=',test_acc*100)
# Out:
# Training Acc= 83.77065111758989
# Testing Acc= 84.12698412698413

# %%
from sklearn.metrics import confusion_matrix
cm3=confusion_matrix(y_test,y_test_pred)
print(cm3)

sns.heatmap(cm3,annot=True,cbar=False,fmt='.1f')
# Out:
# [[371   0]
#  [ 70   0]]
# <AxesSubplot:>

# %%
# Model 4
# Using KNN

from sklearn.neighbors import KNeighborsClassifier
clf4= KNeighborsClassifier()
clf4.fit(x_train,y_train)
y_test_pred=clf4.predict(x_test)
y_train_pred=clf4.predict(x_train)
from sklearn.metrics import accuracy_score
train_acc=accuracy_score(y_train,y_train_pred)
test_acc=accuracy_score(y_test,y_test_pred)
print('Training Acc=',train_acc*100)
print('Testing Acc=',test_acc*100)
# Out:
# Training Acc= 84.8396501457726
# Testing Acc= 82.08616780045351

# %%
from sklearn.metrics import confusion_matrix
cm4=confusion_matrix(y_test,y_test_pred)
print(cm4)

sns.heatmap(cm4,annot=True,cbar=False,fmt='.1f')
# Out:
# [[355  16]
#  [ 63   7]]
# <AxesSubplot:>

# %%
# Model 5
# Using RandomForest Classifier

from sklearn.ensemble import RandomForestClassifier
clf5=RandomForestClassifier()
clf5.fit(x_train,y_train)
y_test_pred=clf5.predict(x_test)
y_train_pred=clf5.predict(x_train)

from sklearn.metrics import accuracy_score
train_acc=accuracy_score(y_train,y_train_pred)
test_acc=accuracy_score(y_test,y_test_pred)
print('Training Acc=',train_acc*100)
print('Testing Acc=',test_acc*100)
# Out:
# Training Acc= 100.0
# Testing Acc= 87.98185941043084

# %%
from sklearn.metrics import confusion_matrix
cm5=confusion_matrix(y_test,y_test_pred)
print(cm5)

sns.heatmap(cm5,annot=True,cbar=False,fmt='.1f')
# Out:
# [[370   1]
#  [ 52  18]]
# <AxesSubplot:>

# %% [markdown]
# Comparison of different models

# %%
#  Compare the performance of different classifier

clf=[clf1,clf2,clf3,clf4,clf5]
name=['LR','DT','SVM','KNN','RF']
accuracy={}
for model,model_name in zip(clf,name):
    model.fit(x_train,y_train)
    acc=accuracy_score(model.predict(x_test),y_test)
    accuracy[model_name]=acc*100
for i,j in accuracy.items():
    print(i,':',j)
    
classifiers=[]
ac=[]
for i,j in accuracy.items():
    classifiers.append(i)
    ac.append(j)

fig = plt.figure(figsize = (10, 5))
#  Bar plot
plt.bar(classifiers,ac,color="Black")
plt.xlabel("models")
plt.ylabel("accuracy")
plt.title("accuracy of different models")
plt.show()
# Out:
# C:\Users\shubhangi\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LR : 84.80725623582767
# DT : 80.95238095238095
# SVM : 84.12698412698413
# KNN : 82.08616780045351
# RF : 87.52834467120182
